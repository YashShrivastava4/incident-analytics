# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
print(PROJECT_ROOT)

RAW_DATA_PATH = PROJECT_ROOT / "data" / "raw"

print(RAW_DATA_PATH)

df = pd.read_csv(RAW_DATA_PATH / "incident_event_log.csv")
# Out:
# d:\1_My Folders\Career\DataField\0_Projects\Data Analyst\Incident Analytics & NL-to-SQL Assistant\incident-analytics
# d:\1_My Folders\Career\DataField\0_Projects\Data Analyst\Incident Analytics & NL-to-SQL Assistant\incident-analytics\data\raw

# %%
df[df['number'].isin(['INC0028089', 'INC0030413'])][
    ['number', 'sys_created_at', 'incident_state', 'resolved_at', 'closed_at', 'closed_code']
].sort_values(['number', 'sys_created_at'])
# Out:
#             number   sys_created_at incident_state      resolved_at  \
# 115640  INC0028089  10/5/2016 22:09            New  16/6/2016 13:02
# 115641  INC0028089  10/5/2016 22:09           -100  16/6/2016 13:02
# 115642  INC0028089  10/5/2016 22:09           -100  16/6/2016 13:02
# 115643  INC0028089  10/5/2016 22:09       Resolved  16/6/2016 13:02
# 115644  INC0028089  10/5/2016 22:09       Resolved  16/6/2016 13:02
# 115645  INC0028089  10/5/2016 22:09         Closed  16/6/2016 13:02
# 124503  INC0030413  17/5/2016 14:45            New  21/6/2016 17:28
# 124504  INC0030413  17/5/2016 14:45            New  21/6/2016 17:28
# 124505  INC0030413  17/5/2016 14:45         Active  21/6/2016 17:28
# 124506  INC0030413  17/5/2016 14:45         Active  21/6/2016 17:28
# 124507  INC0030413  17/5/2016 14:45           -100  21/6/2016 17:28
# 124508  INC0030413  17/5/2016 14:45           -100  21/6/2016 17:28
# 124509  INC0030413  17/5/2016 14:45           -100  21/6/2016 17:28
# ...
